# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/chinki/Downloads/insurance(1).csv")

# %%
df

# %%
df.describe().transpose()

# %%
df.dtypes

# %%
df.isnull().sum()

# %%
df1=df.drop(['sex','smoker','region'],axis=1)

# %%
# Pairplot using sns
import seaborn as sns
sns.pairplot(df1, hue = 'charges')

# %%
import matplotlib.pyplot as plt

# %%
sns.boxplot(y=df['bmi'],x=df['sex'], hue=df['smoker'])

# %%
sns.distplot(df['bmi'],kde=True)
